# %% [markdown]
# ## 3.1.1 층: 딥러닝의 구성 단위

# %% [markdown]
# ### 1. 2D Tensor (samples, features)

# %% [markdown]
# 1. fully connected layer

# %% [markdown]
# y = Wx + b

# %% [markdown]
# ![fully_connected_layer.png](data:image/png;base64,...)

# %% [markdown]
# Fully Connected layer takes input from Flatten Layer which is a one-dimensional layer (1D Layer). The data coming from Flatten Layer is passed first to Affine function and then to Non-Linear function. The combination of 1 Affine function and 1 Non-Linear Function is called as 1 FC (Fully Connected) or 1 Hidden Layer.
#
# Non-Linear Function - Sigmoid, TanH and ReLu

# %% [markdown]
# reference:
# https://indiantechwarrior.com/fully-connected-layers-in-convolutional-neural-networks/

# %% [markdown]
# ### 2.3D tensor (samples, timesteps, features)

# %% [markdown]
# 1. Recurrent Layer

# %% [markdown]
# ![recurrent_layer.png](data:image/png;base64,...)

# %% [markdown]
# sequence: applicable to audio analysis, handwritten recognition

# %% [markdown]
# ![recurrent_layer2.png](data:image/png;base64,...)

# %% [markdown]
# reference: https://towardsdatascience.com/implementation-of-rnn-lstm-and-gru-a4250bf6c090
#
#
# https://www.youtube.com/watch?v=LHXXI4-IEns

# %% [markdown]
# #### 3. 4D tensor

# %% [markdown]
# ![2d_convolution.png](data:image/png;base64,...)

# %% [markdown]
# reference: https://www.youtube.com/watch?v=sTTuaNp5LTw
